# %%
import pandas as pd

# %%
# Read the CSV file
df = pd.read_csv('/home/philipp/Code/BigDataBI/Data/original/arbeitslosenquote.csv')

# Assume the date column is named 'Date', adjust if necessary
df['Date'] = pd.to_datetime(df['DATE'], format='%m/%y').dt.strftime('%m-%d-%Y')

df.head()

df
# Out:
#      DATE  Arbeitslosenquote   Bestand Arbeitslose  Zugang Arbeitslose  \
# 0   11/24                 6.0           28066300.0            562260.0
# 1   10/24                 5.9           27740300.0            554830.0
# 2   09/24                 6.0           27905300.0            614150.0
# 3   08/24                 6.0           28063600.0            536900.0
# 4   07/24                 6.1           28719100.0            591370.0
# 5   06/24                 6.0           28087200.0            639110.0
# 6   05/24                 5.8           27265700.0            501830.0
# 7   04/24                 5.8           27225500.0            530150.0
# 8   03/24                 6.0           27495800.0            594500.0
# 9   02/24                 6.0           27692800.0            544550.0
# 10  01/24                 6.1           28138100.0            579240.0
# 11  12/23                 6.1           28053800.0            633170.0
# ...
